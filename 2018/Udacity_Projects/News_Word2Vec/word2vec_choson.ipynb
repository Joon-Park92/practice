# %% [markdown]
# # Collecing Data from Web

# %%
import pickle
import os
from collections import Counter
from konlpy import tag

# %%
text = ""
file_list = os.listdir(path=os.getcwd()+'/Choson_data')

for file in file_list:
    with open('Choson_data/'+file,'rb') as f:
        data = pickle.load(f)
    for day in range(1,len(data)+1):
        for art_num in range(30):
            for st in data[day][art_num]['contents']:
                text += st

# %%
Analy = tag.Twitter()
nouns = Analy.nouns(text)
nouns_counter = Counter(nouns)

# %%
nouns_counter.most_common()

# %%
with open('embedding_words.pickle','wb') as f:
    pickle.dump(nouns,f,protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# # Check Point

# %%
import numpy as np
import pickle
from collections import Counter

with open('embedding_words.pickle','rb') as f:
    nouns = pickle.load(f)

# %%
print('Total words:{}'.format(len(nouns)))
print("Unique words:{}".format(len(set(nouns))))
# Out:
# Total words:976047
# Unique words:24287

# %%
noun_counter = Counter(nouns)

# %%
noun_counter.most_common()[:100]

# %%
vocab = sorted(set(nouns),key=noun_counter.get,reverse=True) 
vocab_to_int = {voc : idx for idx,voc in enumerate(vocab) }
int_to_vocab ={idx : voc for idx,voc in enumerate(vocab)}

# %% [markdown]
# # Subsampling

# %% [markdown]
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$

# %%
import random
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
thresholds = 1e-3

x = np.linspace(0,1,100)
y = 1- np.sqrt(thresholds/x)

plt.xlabel('Frequency')
plt.ylabel('P_drop_out')
plt.title('Probability of Drop_out')

plt.plot(x,y)
# Out:
# C:\Users\Joon\Anaconda2\envs\ipykernel_py3\lib\site-packages\ipykernel\__main__.py:4: RuntimeWarning: divide by zero encountered in true_divide

# %%
freqs = {noun:count/len(nouns) for noun,count in noun_counter.items()}
p_drop = {noun: 1-np.sqrt(thresholds/freqs[noun]) for noun in vocab}

# %%
train_words = []

for word in nouns:
    if p_drop[word] <= random.random():
        train_words.append(word)

# %%
train_words = [vocab_to_int[ch] for ch in train_words]

# %% [markdown]
# # Making Batches

# %%
def get_target(text,idx,window_size = 5):
    
    R = np.random.randint(1,window_size+1)
    start = idx - R if (idx-R)>0 else 0
    stop = idx + R
    
    target_words = set(text[start:idx]+text[idx+1:stop+1])
    
    return list(target_words)

# %%
def get_batches(text,batch_size,window_size=5):
    
    n_batches = len(text) //batch_size
    text = text[:n_batches*batch_size]
    
    for idx in range(0,len(text),batch_size):
        x,y = [],[]
        batch = text[idx:idx+batch_size]
        
        for ii in range(len(batch)):
            batch_y = get_target(batch,ii,window_size)
            batch_x = batch[ii]
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        
        yield x, y

# %% [markdown]
# # Building Graph

# %%
import tensorflow as tf

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32,[None],name = 'inputs')
    labels = tf.placeholder(tf.int32,[None,None],name = 'labels')

# %%
n_vocab = len(vocab)
n_embedding = 200

with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform([n_vocab,n_embedding],-1,1))
    embed = tf.nn.embedding_lookup(embedding,inputs)

# %% [markdown]
# # Negative Sampling

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal((n_vocab, n_embedding), stddev=0.1))
    softmax_b = tf.Variable(tf.zeros(n_vocab))
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b, 
                                      labels, embed,
                                      n_sampled, n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# # Validation

# %%
with train_graph.as_default():
    valid_size = 16
    valid_window = 100
    
    valid_examples = np.array(random.sample(range(valid_window),valid_size//2))
    valid_examples = np.append(valid_examples,
                              random.sample(range(1000,1000+valid_window),valid_size//2))
    
    valid_dataset = tf.constant(valid_examples,dtype=tf.int32)
    
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding),1,keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding,valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# !mkdir checkpoints

# %% [markdown]
# # Training...

# %%
import time

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    
    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints/text8.ckpt
# Epoch 1/10 Iteration: 100 Avg. Training loss: 3.6802 0.0245 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 3.6113 0.0241 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 3.4198 0.0240 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 3.5285 0.0240 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 3.6764 0.0241 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 3.6273 0.0241 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 3.6725 0.0241 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 3.7015 0.0240 sec/batch
# Epoch 2/10 Iteration: 900 Avg. Training loss: 3.7203 0.0051 sec/batch
# Epoch 2/10 Iteration: 1000 Avg. Training loss: 3.6393 0.0240 sec/batch
# Nearest to 이번: 패배, 구어, 리포트, 송, 멕시코, 김영호, 기회, 출마,
# Nearest to 줄: 생리학, 충족, 씀씀이, 크렘린, 쓴맛, 발문, 이율배반, 탄력,
# Nearest to 정책: 무시, 누누이, 정부, 저급, 완전, 뿜어냈, 선진국, 빈곤층,
# Nearest to 사람: 언짢아, 아줌마, 주위, 아바타, 한밤중, 보르헤스, 역류, 애완견,
# Nearest to 제재: 안보리, 돈줄, 대북, 광물, 결의, 국제사회, 유엔, 제스처,
# Nearest to 공천: 살생, 호도, 공관, 탈락, 직인, 명줄, 계파, 불복,
# Nearest to 일본: 재현, 강세, 도쿄, 백두대간, 병합, 풀잎, 민비, 왜적,
# Nearest to 정치: 국민, 갱도, 퇴보, 필패, 마오, 무것, 폰, 동안,
# Nearest to 바닥: 매니저, 자그마치, 가급, 화롯, 만년필, 아픔, 제각각, 세스,
# Nearest to 디자인: 정경원, 나이키, 마이소르, 쏠쏠, 전기차, 그래픽디자인, 책보, 거장,
# Nearest to 타격: 특수전, 무서움, 동선, 현금화, 사령부, 광둥성, 실시간, 제거,
# Nearest to 그날: 멍에, 복심, 일기장, 모유, 청담동, 주네, 미션, 황무지,
# Nearest to 호텔: 체크, 유료, 허가, 속삭임, 빨, 실토, 접촉, 퍼트,
# Nearest to 팔: 민사소송법, 말리부, 노소, 횡령죄, 흥겹, 자회사, 생신, 살코기,
# Nearest to 기대: 동방예의지국, 자주파, 분위기, 비정상, 마땅치, 다짐, 싱글맘, 관가,
# Nearest to 하늘: 스포츠맨, 남동, 부르주아, 작곡, 층간소음, 칼국수, 근원, 진격,
# Epoch 2/10 Iteration: 1100 Avg. Training loss: 3.5568 0.0245 sec/batch
# Epoch 2/10 Iteration: 1200 Avg. Training loss: 3.3439 0.0241 sec/batch
# Epoch 2/10 Iteration: 1300 Avg. Training loss: 3.5584 0.0241 sec/batch
# Epoch 2/10 Iteration: 1400 Avg. Training loss: 3.6629 0.0241 sec/batch
# Epoch 2/10 Iteration: 1500 Avg. Training loss: 3.6145 0.0240 sec/batch
# Epoch 2/10 Iteration: 1600 Avg. Training loss: 3.6246 0.0242 sec/batch
# Epoch 2/10 Iteration: 1700 Avg. Training loss: 3.6466 0.0242 sec/batch
# Epoch 3/10 Iteration: 1800 Avg. Training loss: 3.6660 0.0101 sec/batch
# Epoch 3/10 Iteration: 1900 Avg. Training loss: 3.5908 0.0240 sec/batch
# Epoch 3/10 Iteration: 2000 Avg. Training loss: 3.4948 0.0240 sec/batch
# Nearest to 이번: 패배, 구어, 자백, 김영호, 선수, 기회, 선거권, 멕시코,
# Nearest to 줄: 생리학, 충족, 씀씀이, 크렘린, 발문, 쓴맛, 문인수, 공당,
# Nearest to 정책: 정부, 누누이, 뿜어냈, 무시, 빈곤층, 완전, 탄소, 선진국,
# Nearest to 사람: 언짢아, 아줌마, 주위, 완, 아바타, 보르헤스, 한밤중, 도자기,
# Nearest to 제재: 안보리, 돈줄, 국제사회, 대북, 광물, 결의, 유엔, 쌩,
# Nearest to 공천: 살생, 호도, 탈락, 불복, 공관, 직인, 매뉴얼, 계파,
# Nearest to 일본: 재현, 강세, 도쿄, 백두대간, 민비, 병합, 성범죄, 풀잎,
# Nearest to 정치: 국민, 퇴보, 갱도, 무것, 필패, 마오, 저쪽, 예법,
# Nearest to 바닥: 매니저, 자그마치, 세스, 가급, 제각각, 만년필, 소방관, 화롯,
# Nearest to 디자인: 나이키, 정경원, 그래픽디자인, 쏠쏠, 전기차, 마이소르, 거장, 디자이너,
# Nearest to 타격: 특수전, 동선, 무서움, 현금화, 사령부, 광둥성, 제거, 실시간,
# Nearest to 그날: 복심, 멍에, 일기장, 모유, 주네, 변치, 청담동, 미션,
# Nearest to 호텔: 체크, 유료, 허가, 속삭임, 실토, 빨, 접촉, 뷰티,
# Nearest to 팔: 민사소송법, 말리부, 노소, 횡령죄, 흥겹, 자회사, 생신, 입심,
# Nearest to 기대: 동방예의지국, 자주파, 분위기, 비정상, 마땅치, 다짐, 싱글맘, 차만,
# Nearest to 하늘: 스포츠맨, 남동, 부르주아, 칼국수, 층간소음, 작곡, 근원, 진격,
# Epoch 3/10 Iteration: 2100 Avg. Training loss: 3.3011 0.0244 sec/batch
# Epoch 3/10 Iteration: 2200 Avg. Training loss: 3.5493 0.0241 sec/batch
# Epoch 3/10 Iteration: 2300 Avg. Training loss: 3.6159 0.0239 sec/batch
# Epoch 3/10 Iteration: 2400 Avg. Training loss: 3.5689 0.0241 sec/batch
# Epoch 3/10 Iteration: 2500 Avg. Training loss: 3.6257 0.0241 sec/batch
# Epoch 3/10 Iteration: 2600 Avg. Training loss: 3.6110 0.0239 sec/batch
# Epoch 4/10 Iteration: 2700 Avg. Training loss: 3.6530 0.0149 sec/batch
# Epoch 4/10 Iteration: 2800 Avg. Training loss: 3.5355 0.0236 sec/batch
# Epoch 4/10 Iteration: 2900 Avg. Training loss: 3.4623 0.0236 sec/batch
# Epoch 4/10 Iteration: 3000 Avg. Training loss: 3.2898 0.0236 sec/batch
# Nearest to 이번: 패배, 구어, 선거권, 간과, 기회, 선수, 김영호, 멕시코,
# Nearest to 줄: 생리학, 녹말, 쓴맛, 충족, 씀씀이, 문인수, 발문, 이율배반,
# Nearest to 정책: 뿜어냈, 탄소, 무시, 정부, 누누이, 완전, 빈곤층, 퇴장,
# Nearest to 사람: 언짢아, 완, 주위, 아줌마, 구우, 낯선, 보르헤스, 아바타,
# Nearest to 제재: 돈줄, 안보리, 대북, 광물, 국제사회, 결의, 쌩, 유엔,
# Nearest to 공천: 살생, 탈락, 호도, 불복, 계파, 공관, 매뉴얼, 직인,
# Nearest to 일본: 재현, 강세, 도쿄, 백두대간, 열도, 성범죄, 민비, 병합,
# Nearest to 정치: 국민, 갱도, 무것, 퇴보, 필패, 저쪽, 예법, 마오,
# Nearest to 바닥: 세스, 매니저, 자그마치, 가급, 화롯, 제각각, 소방관, 키안,
# Nearest to 디자인: 정경원, 나이키, 그래픽디자인, 디자이너, 거장, 반팔, 전기차, 책보,
# Nearest to 타격: 동선, 특수전, 무서움, 현금화, 실시간, 제거, 사령부, 광둥성,
# Nearest to 그날: 복심, 멍에, 일기장, 모유, 주네, 소도, 변치, 통틀어,
# Nearest to 호텔: 체크, 유료, 허가, 속삭임, 빨, 실토, 접촉, 가슴속,
# Nearest to 팔: 민사소송법, 말리부, 노소, 횡령죄, 흥겹, 자회사, 생신, 입심,
# Nearest to 기대: 동방예의지국, 마땅치, 자주파, 비정상, 다짐, 분위기, 싱글맘, 경구,
# Nearest to 하늘: 스포츠맨, 남동, 층간소음, 부르주아, 칼국수, 작곡, 근원, 오늘,
# Epoch 4/10 Iteration: 3100 Avg. Training loss: 3.5384 0.0240 sec/batch
# Epoch 4/10 Iteration: 3200 Avg. Training loss: 3.5787 0.0237 sec/batch
# Epoch 4/10 Iteration: 3300 Avg. Training loss: 3.5279 0.0236 sec/batch
# Epoch 4/10 Iteration: 3400 Avg. Training loss: 3.5896 0.0237 sec/batch
# Epoch 4/10 Iteration: 3500 Avg. Training loss: 3.5922 0.0237 sec/batch
# Epoch 5/10 Iteration: 3600 Avg. Training loss: 3.5590 0.0198 sec/batch
# Epoch 5/10 Iteration: 3700 Avg. Training loss: 3.4973 0.0236 sec/batch
# Epoch 5/10 Iteration: 3800 Avg. Training loss: 3.3643 0.0236 sec/batch
# Epoch 5/10 Iteration: 3900 Avg. Training loss: 3.3252 0.0235 sec/batch
# Epoch 5/10 Iteration: 4000 Avg. Training loss: 3.5271 0.0235 sec/batch
# Nearest to 이번: 패배, 선거권, 간과, 구어, 센카쿠, 멕시코, 수임, 기회,
# Nearest to 줄: 생리학, 쓴맛, 씀씀이, 녹말, 충족, 문인수, 발문, 이율배반,
# Nearest to 정책: 뿜어냈, 탄소, 누누이, 무시, 정부, 완전, 빈곤층, 퇴장,
# Nearest to 사람: 언짢아, 주위, 완, 구우, 아줌마, 도자기, 한밤중, 에너지,
# Nearest to 제재: 안보리, 돈줄, 광물, 대북, 결의, 국제사회, 안과, 유엔,
# Nearest to 공천: 탈락, 살생, 계파, 불복, 공관, 호도, 매뉴얼, 젠트리피케이션,
# Nearest to 일본: 강세, 백두대간, 재현, 도쿄, 열도, 다케시마, 성범죄, 풀잎,
# Nearest to 정치: 국민, 갱도, 무것, 필패, 퇴보, 저쪽, 동안, 마오,
# Nearest to 바닥: 매니저, 세스, 제각각, 화롯, 자그마치, 가급, 소방관, 키안,
# Nearest to 디자인: 나이키, 정경원, 그래픽디자인, 데이비슨, 디자이너, 전기차, 반팔, 스테파노,
# Nearest to 타격: 동선, 특수전, 무서움, 실시간, 현금화, 옥녀봉, 광둥성, 제거,
# Nearest to 그날: 복심, 멍에, 일기장, 모유, 주네, 변치, 소도, 통틀어,
# Nearest to 호텔: 체크, 유료, 허가, 속삭임, 실토, 빨, 접촉, 가슴속,
# Nearest to 팔: 민사소송법, 말리부, 노소, 횡령죄, 자회사, 흥겹, 입심, 시보,
# Nearest to 기대: 동방예의지국, 다짐, 비정상, 분위기, 마땅치, 자주파, 싱글맘, 경구,
# Nearest to 하늘: 스포츠맨, 남동, 작곡, 층간소음, 칼국수, 부르주아, 근원, 오늘,
# Epoch 5/10 Iteration: 4100 Avg. Training loss: 3.5296 0.0240 sec/batch
# Epoch 5/10 Iteration: 4200 Avg. Training loss: 3.5268 0.0235 sec/batch
# Epoch 5/10 Iteration: 4300 Avg. Training loss: 3.5482 0.0236 sec/batch
# Epoch 6/10 Iteration: 4400 Avg. Training loss: 3.5907 0.0012 sec/batch
# Epoch 6/10 Iteration: 4500 Avg. Training loss: 3.5124 0.0236 sec/batch
# Epoch 6/10 Iteration: 4600 Avg. Training loss: 3.4466 0.0235 sec/batch
# Epoch 6/10 Iteration: 4700 Avg. Training loss: 3.2634 0.0238 sec/batch
# Epoch 6/10 Iteration: 4800 Avg. Training loss: 3.3894 0.0237 sec/batch
# Epoch 6/10 Iteration: 4900 Avg. Training loss: 3.5472 0.0237 sec/batch
# Epoch 6/10 Iteration: 5000 Avg. Training loss: 3.4866 0.0235 sec/batch
# Nearest to 이번: 패배, 선거권, 간과, 구어, 개개인, 자백, 극우, 센카쿠,
# Nearest to 줄: 생리학, 쓴맛, 녹말, 충족, 씀씀이, 문인수, 발문, 복수심,
# Nearest to 정책: 뿜어냈, 탄소, 완전, 무시, 누누이, 퇴장, 정부, 빈곤층,
# Nearest to 사람: 언짢아, 구우, 주위, 완, 년경, 지능, 수담, 아줌마,
# Nearest to 제재: 안보리, 돈줄, 광물, 대북, 국제사회, 결의, 쌩, 유엔,
# Nearest to 공천: 탈락, 살생, 계파, 불복, 공관, 직인, 호도, 이한구,
# Nearest to 일본: 강세, 백두대간, 도쿄, 열도, 다케시마, 재현, 민족사, 국방력,
# Nearest to 정치: 국민, 퇴보, 갱도, 무것, 필패, 저쪽, 마오, 예법,
# Nearest to 바닥: 매니저, 세스, 자그마치, 화롯, 소방관, 제각각, 키안, 버진아일랜드,
# Nearest to 디자인: 정경원, 나이키, 그래픽디자인, 데이비슨, 디자이너, 전기차, 고심, 스테파노,
# Nearest to 타격: 동선, 특수전, 옥녀봉, 실시간, 현금화, 무서움, 광둥성, 제거,
# Nearest to 그날: 복심, 멍에, 일기장, 주네, 모유, 변치, 가리비, 청룡영화제,
# Nearest to 호텔: 체크, 유료, 허가, 속삭임, 실토, 가슴속, 신라, 빨,
# Nearest to 팔: 민사소송법, 말리부, 노소, 횡령죄, 자회사, 흥겹, 입심, 시보,
# Nearest to 기대: 동방예의지국, 다짐, 분위기, 싱글맘, 마땅치, 자주파, 비정상, 바란,
# Nearest to 하늘: 스포츠맨, 남동, 칼국수, 작곡, 층간소음, 손견, 부르주아, 찬비,
# Epoch 6/10 Iteration: 5100 Avg. Training loss: 3.5101 0.0239 sec/batch
# Epoch 6/10 Iteration: 5200 Avg. Training loss: 3.5587 0.0236 sec/batch
# Epoch 7/10 Iteration: 5300 Avg. Training loss: 3.5649 0.0061 sec/batch
# Epoch 7/10 Iteration: 5400 Avg. Training loss: 3.4912 0.0236 sec/batch
# Epoch 7/10 Iteration: 5500 Avg. Training loss: 3.4019 0.0236 sec/batch
# Epoch 7/10 Iteration: 5600 Avg. Training loss: 3.2065 0.0235 sec/batch
# Epoch 7/10 Iteration: 5700 Avg. Training loss: 3.4376 0.0235 sec/batch
# Epoch 7/10 Iteration: 5800 Avg. Training loss: 3.5146 0.0236 sec/batch
# Epoch 7/10 Iteration: 5900 Avg. Training loss: 3.4588 0.0236 sec/batch
# Epoch 7/10 Iteration: 6000 Avg. Training loss: 3.5030 0.0235 sec/batch
# Nearest to 이번: 패배, 선거권, 개개인, 구어, 간과, 극우, 압승하, 자백,
# Nearest to 줄: 생리학, 쓴맛, 녹말, 충족, 발문, 복수심, 문인수, 씀씀이,
# Nearest to 정책: 뿜어냈, 탄소, 퇴장, 누누이, 완전, 무시, 상호주, 빈곤층,
# Nearest to 사람: 주위, 언짢아, 완, 구우, 도자기, 피톤치드, 날렵하, 아줌마,
# Nearest to 제재: 안보리, 대북, 광물, 돈줄, 국제사회, 결의, 안과, 쌩,
# Nearest to 공천: 탈락, 살생, 공관, 불복, 계파, 호도, 이한구, 젠트리피케이션,
# Nearest to 일본: 강세, 백두대간, 다케시마, 도쿄, 열도, 국방력, 재현, 센카쿠열도,
# Nearest to 정치: 국민, 퇴보, 무것, 갱도, 필패, 저쪽, 동안, 연목,
# Nearest to 바닥: 매니저, 세스, 버진아일랜드, 제각각, 합계출산율, 소방관, 자그마치, 키안,
# Nearest to 디자인: 정경원, 나이키, 그래픽디자인, 데이비슨, 디자이너, 스테파노, 반팔, 고심,
# Nearest to 타격: 동선, 옥녀봉, 특수전, 현금화, 실시간, 광개토왕릉비, 광물, 무서움,
# Nearest to 그날: 복심, 멍에, 일기장, 변치, 주네, 모유, 가리비, 소도,
# Nearest to 호텔: 유료, 체크, 허가, 속삭임, 실토, 가슴속, 빨, 접촉,
# Nearest to 팔: 민사소송법, 말리부, 횡령죄, 노소, 입심, 자회사, 시보, 흥겹,
# Nearest to 기대: 다짐, 동방예의지국, 분위기, 싱글맘, 마땅치, 비정상, 틈새, 바란,
# Nearest to 하늘: 스포츠맨, 남동, 칼국수, 손견, 층간소음, 찬비, 작곡, 코끝,
# Epoch 7/10 Iteration: 6100 Avg. Training loss: 3.5183 0.0240 sec/batch
# Epoch 8/10 Iteration: 6200 Avg. Training loss: 3.5189 0.0110 sec/batch
# Epoch 8/10 Iteration: 6300 Avg. Training loss: 3.4586 0.0236 sec/batch
# Epoch 8/10 Iteration: 6400 Avg. Training loss: 3.3698 0.0235 sec/batch
# Epoch 8/10 Iteration: 6500 Avg. Training loss: 3.1850 0.0237 sec/batch
# Epoch 8/10 Iteration: 6600 Avg. Training loss: 3.4501 0.0235 sec/batch
# Epoch 8/10 Iteration: 6700 Avg. Training loss: 3.4828 0.0236 sec/batch
# Epoch 8/10 Iteration: 6800 Avg. Training loss: 3.4220 0.0236 sec/batch
# Epoch 8/10 Iteration: 6900 Avg. Training loss: 3.4718 0.0237 sec/batch
# Epoch 8/10 Iteration: 7000 Avg. Training loss: 3.4902 0.0235 sec/batch
# Nearest to 이번: 패배, 선거권, 개개인, 구어, 압승하, 센카쿠, 자백, 주어,
# Nearest to 줄: 생리학, 쓴맛, 복수심, 녹말, 충족, 발문, 씀씀이, 문인수,
# Nearest to 정책: 뿜어냈, 누누이, 퇴장, 탄소, 정부, 완전, 빈곤층, 무시,
# Nearest to 사람: 주위, 구우, 언짢아, 완, 도자기, 수담, 피톤치드, 날렵하,
# Nearest to 제재: 안보리, 대북, 광물, 돈줄, 국제사회, 결의, 안과, 쌩,
# Nearest to 공천: 탈락, 살생, 불복, 계파, 공관, 호도, 이한구, 매뉴얼,
# Nearest to 일본: 다케시마, 백두대간, 강세, 도쿄, 열도, 국방력, 재현, 센카쿠열도,
# Nearest to 정치: 국민, 퇴보, 저쪽, 필패, 연목, 무것, 마오, 동안,
# Nearest to 바닥: 세스, 매니저, 버진아일랜드, 소방관, 제각각, 화롯, 자그마치, 천연기념물,
# Nearest to 디자인: 정경원, 그래픽디자인, 나이키, 데이비슨, 디자이너, 스테파노, 전기차, 대표이사,
# Nearest to 타격: 동선, 옥녀봉, 특수전, 광개토왕릉비, 무서움, 현금화, 광물, 출병,
# Nearest to 그날: 복심, 멍에, 일기장, 변치, 주네, 모유, 청룡영화제, 가리비,
# Nearest to 호텔: 체크, 허가, 유료, 속삭임, 실토, 가슴속, 신라, 빨,
# Nearest to 팔: 민사소송법, 말리부, 노소, 횡령죄, 입심, 자회사, 시보, 흥겹,
# Nearest to 기대: 동방예의지국, 다짐, 분위기, 싱글맘, 바란, 무르익었, 비정상, 가슴,
# Nearest to 하늘: 스포츠맨, 칼국수, 찬비, 남동, 손견, 날줄, 층간소음, 코끝,
# Epoch 9/10 Iteration: 7100 Avg. Training loss: 3.5265 0.0160 sec/batch
# Epoch 9/10 Iteration: 7200 Avg. Training loss: 3.4219 0.0236 sec/batch
# Epoch 9/10 Iteration: 7300 Avg. Training loss: 3.3383 0.0237 sec/batch
# Epoch 9/10 Iteration: 7400 Avg. Training loss: 3.2199 0.0235 sec/batch
# Epoch 9/10 Iteration: 7500 Avg. Training loss: 3.4348 0.0236 sec/batch
# Epoch 9/10 Iteration: 7600 Avg. Training loss: 3.4596 0.0235 sec/batch
# Epoch 9/10 Iteration: 7700 Avg. Training loss: 3.4150 0.0236 sec/batch
# Epoch 9/10 Iteration: 7800 Avg. Training loss: 3.4631 0.0236 sec/batch
# Epoch 9/10 Iteration: 7900 Avg. Training loss: 3.4722 0.0235 sec/batch
# Epoch 10/10 Iteration: 8000 Avg. Training loss: 3.4521 0.0210 sec/batch
# Nearest to 이번: 패배, 선거권, 개개인, 구어, 극우, 압승하, 부천, 센카쿠,
# Nearest to 줄: 생리학, 복수심, 녹말, 문인수, 쓴맛, 충족, 마력, 발문,
# Nearest to 정책: 누누이, 뿜어냈, 퇴장, 완전, 무시, 정부, 빈곤층, 선진국,
# Nearest to 사람: 주위, 구우, 언짢아, 수담, 피톤치드, 완, 날렵하, 아줌마,
# Nearest to 제재: 안보리, 대북, 국제사회, 광물, 돈줄, 결의, 안과, 유엔,
# Nearest to 공천: 탈락, 살생, 계파, 불복, 공관, 호도, 이한구, 더럽힌,
# Nearest to 일본: 다케시마, 백두대간, 강세, 도쿄, 국방력, 센카쿠열도, 열도, 성범죄,
# Nearest to 정치: 국민, 필패, 퇴보, 무것, 저쪽, 연목, 동안, 갱도,
# Nearest to 바닥: 소방관, 세스, 버진아일랜드, 매니저, 키안, 천지, 제각각, 화롯,
# Nearest to 디자인: 정경원, 그래픽디자인, 나이키, 데이비슨, 디자이너, 전기차, 대표이사, 고심,
# Nearest to 타격: 동선, 특수전, 옥녀봉, 광개토왕릉비, 출병, 현금화, 무서움, 광물,
# Nearest to 그날: 복심, 멍에, 변치, 일기장, 주네, 청룡영화제, 모유, 가리비,
# Nearest to 호텔: 유료, 허가, 체크, 속삭임, 신라, 가슴속, 접촉, 실토,
# Nearest to 팔: 민사소송법, 말리부, 횡령죄, 노소, 입심, 시보, 권선, 자회사,
# Nearest to 기대: 동방예의지국, 다짐, 분위기, 무르익었, 싱글맘, 가슴, 일궈놓, 비정상,
# Nearest to 하늘: 스포츠맨, 찬비, 칼국수, 손견, 남동, 작곡, 층간소음, 날줄,
# Epoch 10/10 Iteration: 8100 Avg. Training loss: 3.3896 0.0240 sec/batch
# Epoch 10/10 Iteration: 8200 Avg. Training loss: 3.2511 0.0235 sec/batch
# Epoch 10/10 Iteration: 8300 Avg. Training loss: 3.2697 0.0236 sec/batch
# Epoch 10/10 Iteration: 8400 Avg. Training loss: 3.4312 0.0235 sec/batch
# Epoch 10/10 Iteration: 8500 Avg. Training loss: 3.4321 0.0235 sec/batch
# Epoch 10/10 Iteration: 8600 Avg. Training loss: 3.4109 0.0235 sec/batch
# Epoch 10/10 Iteration: 8700 Avg. Training loss: 3.4587 0.0236 sec/batch

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints\text8.ckpt

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)

# %%
from matplotlib import font_manager, rc
font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
rc('font', family=font_name)
